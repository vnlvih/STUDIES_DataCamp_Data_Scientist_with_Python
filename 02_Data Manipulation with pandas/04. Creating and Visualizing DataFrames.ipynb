# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Creating and Visualizing DataFrames**

# %% [markdown]
# **Visualizing your data**
#
# Which avocado size is most popular?

# %%
avocados = pd.read_pickle("/content/drive/MyDrive/Colab Notebooks/DATACAMP/01. Data Scientist with Python/00.DATABASES/avoplotto.pkl")
avocados.head()
# Out:
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76
# 2  2015-12-13  conventional  2015       0.93  small  9855053.66
# 3  2015-12-06  conventional  2015       0.89  small  9405464.36
# 4  2015-11-29  conventional  2015       0.99  small  8094803.56

# %%
# Import matplotlib.pyplot with alias plt
import matplotlib.pyplot as plt

# %%
# Look at the first few rows of data
print(avocados.head())
# Out:
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76
# 2  2015-12-13  conventional  2015       0.93  small  9855053.66
# 3  2015-12-06  conventional  2015       0.89  small  9405464.36
# 4  2015-11-29  conventional  2015       0.99  small  8094803.56

# %%
# Get the total number of avocados sold of each size
nb_sold_by_size = avocados.groupby("size")["nb_sold"].sum()
print(nb_sold_by_size)
# Out:
# size
# extra_large    1.561752e+08
# large          2.015012e+09
# small          2.054936e+09
# Name: nb_sold, dtype: float64

# %%
# Create a bar plot of the number of avocados sold by size
nb_sold_by_size.plot(kind="bar")

# Show the plot

plt.show()

# %% [markdown]
# **Changes in sales over time**

# %%
avocados.columns
# Out:
# Index(['date', 'type', 'year', 'avg_price', 'size', 'nb_sold'], dtype='object')

# %%
# Get the total number of avocados sold on each date
nb_sold_by_date = avocados.groupby("date")["nb_sold"].sum()
print(nb_sold_by_date)
# Out:
# date
# 2015-01-04    27279606.03
# 2015-01-11    25081927.33
# 2015-01-18    24961540.48
# 2015-01-25    24094678.66
# 2015-02-01    39838734.08
#                  ...
# 2018-02-25    25434002.74
# 2018-03-04    26834303.05
# 2018-03-11    26094044.41
# 2018-03-18    26030618.97
# 2018-03-25    27480242.92
# Name: nb_sold, Length: 169, dtype: float64

# %%
# Create a line plot of the number of avocados sold by date
nb_sold_by_date.plot(kind = "line")

# Show the plot
plt.show()

# %% [markdown]
# **Avocado supply and demand**

# %%
# Scatter plot of nb_sold vs avg_price with title
avocados.plot(x = "nb_sold", y = "avg_price", kind = "scatter", title = "Number of avocados sold vs. average price")

# Show the plot

plt.show()

# %% [markdown]
# **Price of conventional vs. organic avocados**

# %%
avocados.head()
# Out:
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76
# 2  2015-12-13  conventional  2015       0.93  small  9855053.66
# 3  2015-12-06  conventional  2015       0.89  small  9405464.36
# 4  2015-11-29  conventional  2015       0.99  small  8094803.56

# %%
# Histogram of conventional avg_price 
avocados[avocados["type"] == "conventional"]["avg_price"].hist()
# Histogram of organic avg_price
avocados[avocados["type"] == "organic"]["avg_price"].hist()
# Add a legend
plt.legend(["Conventional","Organic"])
# Show the plot
plt.show()

# %%
#With transparencia

# Histogram of conventional avg_price 
avocados[avocados["type"] == "conventional"]["avg_price"].hist(alpha = 0.7,bins=20)
# Histogram of organic avg_price
avocados[avocados["type"] == "organic"]["avg_price"].hist(alpha = 0.7,bins=20)
# Add a legend
plt.legend(["Conventional","Organic"])
# Show the plot
plt.show()

# %% [markdown]
# **Missing values**
#
# Finding missing values

# %%
# Print a DataFrame that shows whether each value in avocados_2016 is missing or not.
avocados_2016 = avocados[avocados["year"] == 2016]
print(avocados_2016)
# Out:
#            date          type  year  avg_price         size      nb_sold
# 52   2016-12-25  conventional  2016       1.00        small   9255125.20
# 53   2016-12-18  conventional  2016       0.96        small   9394065.91
# 54   2016-12-11  conventional  2016       0.98        small   9009996.11
# 55   2016-12-04  conventional  2016       1.00        small  11043350.90
# 56   2016-11-27  conventional  2016       1.21        small   7891487.94
# ..          ...           ...   ...        ...          ...          ...
# 944  2016-01-31       organic  2016       1.43  extra_large      5515.91
# 945  2016-01-24       organic  2016       1.41  extra_large     12933.97
# 946  2016-01-17       organic  2016       1.44  extra_large     13106.29
# 947  2016-01-10       organic  2016       1.35  extra_large      8771.79
# 948  2016-01-03       organic  2016       1.43  extra_large      7749.40
#
# [312 rows x 6 columns]

# %%
avocados_2016.loc[:,"small_sold"] = np.nan 
avocados_2016.loc[:,"large_sold"] = np.nan
avocados_2016.loc[:,"xl_sold"] = np.nan
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
avocados_2016.isna()
# Out:
#       date   type   year  avg_price  ...  nb_sold  small_sold  large_sold  xl_sold
# 52   False  False  False      False  ...    False        True        True     True
# 53   False  False  False      False  ...    False        True        True     True
# 54   False  False  False      False  ...    False        True        True     True
# 55   False  False  False      False  ...    False        True        True     True
# 56   False  False  False      False  ...    False        True        True     True
# ..     ...    ...    ...        ...  ...      ...         ...         ...      ...
# 944  False  False  False      False  ...    False        True        True     True
# 945  False  False  False      False  ...    False        True        True     True
# 946  False  False  False      False  ...    False        True        True     True
# 947  False  False  False      False  ...    False        True        True     True
# 948  False  False  False      False  ...    False        True        True     True
#
# [312 rows x 9 columns]

# %%
# Print a summary that shows whether any value in each column is missing or not.
avocados_2016.isna().any()
# Out:
# date          False
# type          False
# year          False
# avg_price     False
# size          False
# nb_sold       False
# small_sold     True
# large_sold     True
# xl_sold        True
# dtype: bool

# %%
#counting missing values
avocados_2016.isna().sum()
# Out:
# date            0
# type            0
# year            0
# avg_price       0
# size            0
# nb_sold         0
# small_sold    312
# large_sold    312
# xl_sold       312
# dtype: int64

# %%
# Bar plot of missing values by variable
avocados_2016.isna().sum().plot(kind = "bar")

# Show plot
plt.show()

# %% [markdown]
# **Removing missing values**

# %%
# Remove rows with missing values
avocados_2016.dropna()
# Out:
# Empty DataFrame
# Columns: [date, type, year, avg_price, size, nb_sold, small_sold, large_sold, xl_sold]
# Index: []

# %%
# Check if any columns contain missing values
avocados_2016.isna().any()
# Out:
# date          False
# type          False
# year          False
# avg_price     False
# size          False
# nb_sold       False
# small_sold     True
# large_sold     True
# xl_sold        True
# dtype: bool

# %% [markdown]
# **Replacing missing values**

# %%
# From previous step
cols_with_missing = ["small_sold", "large_sold", "xl_sold"]
avocados_2016[cols_with_missing].hist()
plt.show()

# Fill in missing values with 0
avocados_2016.fillna(0,inplace=True)
# Create histograms of the filled columns
avocados_2016[cols_with_missing].hist()
# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %% [markdown]
# **Creating DataFrames**
#
# List of dictionaries
# - Constructed row by row

# %%
# Create a list of dictionaries with new data
avocados_list = [
    {'date': "2019-11-03", 'small_sold': 10376832, 'large_sold': 7835071},
    {'date': "2019-11-10", 'small_sold': 10717154, 'large_sold': 8561348},
]

# Convert list into DataFrame
DF_avocados_list = pd.DataFrame(avocados_list)

# Print the new DataFrame
print(DF_avocados_list)
# Out:
#          date  small_sold  large_sold
# 0  2019-11-03    10376832     7835071
# 1  2019-11-10    10717154     8561348

# %% [markdown]
# **Dictionary of lists**
#
# - Constructed column by column

# %%
# Create a dictionary of lists with new data
avocados_dict = {
  "date": ["2019-11-17", "2019-12-01"],
  "small_sold": [10859987, 9291631],
  "large_sold": [7674135, 6238096]
}

# Convert dictionary into DataFrame

DF_avocados_dict = pd.DataFrame(avocados_dict)

# Print the new DataFrame

print(DF_avocados_dict)
# Out:
#          date  small_sold  large_sold
# 0  2019-11-17    10859987     7674135
# 1  2019-12-01     9291631     6238096

# %% [markdown]
# ## **Reading and writing CSVs**

# %% [markdown]
# **CSV to DataFrame**

# %%
# Read CSV as DataFrame called airline_bumping
airline_bumping = pd.read_csv("airline_bumping.csv")

# Take a look at the DataFrame
print(airline_bumping.head())

# For each airline, select nb_bumped and total_passengers and sum
airline_totals = airline_bumping.groupby("airline")[["nb_bumped", "total_passengers"]].sum()

# Create new col, bumps_per_10k: no. of bumps per 10k passengers for each airline
airline_totals["bumps_per_10k"] = airline_totals["nb_bumped"] / airline_totals["total_passengers"] * 10000

# Print airline_totals
print(airline_totals)

# %% [markdown]
# **DataFrame to CSV**

# %%
# Create airline_totals_sorted
airline_totals_sorted = airline_totals.sort_values('bumps_per_10k', ascending=False)

# Print airline_totals_sorted
print(airline_totals_sorted)

# Save as airline_totals_sorted.csv
airline_totals_sorted.to_csv("airline_totals_sorted.csv")
